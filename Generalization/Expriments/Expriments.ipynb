# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
## Clone repository
# %cd /content/drive/MyDrive/master-ut
# !git clone https://github.com/zeinabyazdani/Trustworthy-AI-Mini-Projects.git

# %%
# Update changes in repo
# %cd /content/drive/MyDrive/master-ut/Trustworthy-AI-Mini-Projects
# !git pull origin main
# %cd './Generalization'
# Out:
# /content/drive/MyDrive/master-ut/Trustworthy-AI-Mini-Projects
# remote: Enumerating objects: 9, done.
# remote: Counting objects: 100% (9/9), done.
# remote: Compressing objects: 100% (1/1), done.
# remote: Total 5 (delta 3), reused 5 (delta 3), pack-reused 0 (from 0)
# Unpacking objects: 100% (5/5), 395 bytes | 0 bytes/s, done.
# From https://github.com/zeinabyazdani/Trustworthy-AI-Mini-Projects
#  * branch            main       -> FETCH_HEAD
#    6c5e47b..a0e021f  main       -> origin/main
# Updating 6c5e47b..a0e021f
# Fast-forward
#  Generalization/config/config.yaml | 2 +-
#  1 file changed, 1 insertion(+), 1 deletion(-)
# /content/drive/MyDrive/master-ut/Trustworthy-AI-Mini-Projects/Generalization

# %%
import sys
sys.path.append("/content/drive/MyDrive/master-ut/Trustworthy-AI-Mini-Projects/Generalization")

# %% [markdown]
# ## Train ResNet 18 on the SVHN dataset and test on both SVHN and MNIST

# %%
from scripts import main
# Out:
# Base Directory: /content/drive/MyDrive/master-ut/Trustworthy-AI-Mini-Projects/Generalization
# cuda available? True
# Using downloaded and verified file: /content/drive/MyDrive/master-ut/Trustworthy-AI-Mini-Projects/Generalization/data/dataset/train_32x32.mat
# Using downloaded and verified file: /content/drive/MyDrive/master-ut/Trustworthy-AI-Mini-Projects/Generalization/data/dataset/test_32x32.mat
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-0.77521..0.40906325].
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-2.117904..2.64].
# svhn_train_ds: 65932,
# mnist_train_ds: 59932,
# svhn_test_ds: 26032,
# mnist_test_ds: 10000
# Plot sample image from SVHN dataset
# Plot sample image from MNIST dataset
# epoch = 1, Train loss = 0.9207, Val loss = 0.4192
# epoch = 2, Train loss = 0.3876, Val loss = 0.3484
# epoch = 3, Train loss = 0.2977, Val loss = 0.3158
# epoch = 4, Train loss = 0.2463, Val loss = 0.2789
# epoch = 5, Train loss = 0.2047, Val loss = 0.2766
# epoch = 6, Train loss = 0.1768, Val loss = 0.2811
# epoch = 7, Train loss = 0.0937, Val loss = 0.2395
# epoch = 8, Train loss = 0.0684, Val loss = 0.2551
# epoch = 9, Train loss = 0.0560, Val loss = 0.2661
# epoch = 10, Train loss = 0.0455, Val loss = 0.2862
# Model Performance on SVHN test set
# 0.9325061440467834
# Model Performance on MNIST test set
# 0.5845000147819519

# %% [markdown]
# # Generalization Strategies

# %% [markdown]
# ### Dropout and Batch Normalization
# Investigate the impact of removing Batch Normalization (BN) from ResNet-18.
#
# **Set " use_batch_norm: False " and " model_name    : 'removedBN_model' " in config.yaml**

# %%
from scripts import main
# Out:
# Base Directory: /content/drive/MyDrive/master-ut/Trustworthy-AI-Mini-Projects/Generalization
# cuda available? True
# Using downloaded and verified file: /content/drive/MyDrive/master-ut/Trustworthy-AI-Mini-Projects/Generalization/data/dataset/train_32x32.mat
# Using downloaded and verified file: /content/drive/MyDrive/master-ut/Trustworthy-AI-Mini-Projects/Generalization/data/dataset/test_32x32.mat
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-0.77521..0.40906325].
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-2.117904..2.64].
# svhn_train_ds: 65932,
# mnist_train_ds: 59932,
# svhn_test_ds: 26032,
# mnist_test_ds: 10000
# Plot sample image from SVHN dataset
# Plot sample image from MNIST dataset
# epoch = 1, Train loss = 1.5030, Val loss = 0.6077
# epoch = 2, Train loss = 0.4779, Val loss = 0.4023
# epoch = 3, Train loss = 0.3541, Val loss = 0.3703
# epoch = 4, Train loss = 0.2962, Val loss = 0.3152
# epoch = 5, Train loss = 0.2507, Val loss = 0.3065
# epoch = 6, Train loss = 0.2155, Val loss = 0.3037
# epoch = 7, Train loss = 0.1285, Val loss = 0.2468
# epoch = 8, Train loss = 0.1063, Val loss = 0.2496
# epoch = 9, Train loss = 0.0947, Val loss = 0.2567
# epoch = 10, Train loss = 0.0856, Val loss = 0.2551
# Model Performance on SVHN test set
# 0.9320067763328552
# Model Performance on MNIST test set
# 0.6118000149726868

# %% [markdown]
# ### Loss function
# Utilize Label Smoothing Cross Entropy (adding Label Smoothing Regularization to standard Cross Entropy).
#
# Label smoothing replaces one-hot encoded label vector y_hot with a mixture of y_hot and the uniform distribution:
#
# y_ls = (1 - α) * y_hot + α / K
#
# where K is the number of label classes, and α is a hyperparameter that determines the amount of smoothing. If α = 0, we obtain the original one-hot encoded y_hot. If α = 1, we get the uniform distribution.
#
# https://medium.com/towards-data-science/what-is-label-smoothing-108debd7ef06
#
# **Set " loss_function : 'LSCE' " and " model_name    : 'LSCEloss_model' " in config.yaml**

# %%
from scripts import main
# Out:
# Base Directory: /content/drive/MyDrive/master-ut/Trustworthy-AI-Mini-Projects/Generalization
# cuda available? True
# Using downloaded and verified file: /content/drive/MyDrive/master-ut/Trustworthy-AI-Mini-Projects/Generalization/data/dataset/train_32x32.mat
# Using downloaded and verified file: /content/drive/MyDrive/master-ut/Trustworthy-AI-Mini-Projects/Generalization/data/dataset/test_32x32.mat
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-1.8781574..1.8158263].
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-2.117904..2.64].
# svhn_train_ds: 65932,
# mnist_train_ds: 59932,
# svhn_test_ds: 26032,
# mnist_test_ds: 10000
# Plot sample image from SVHN dataset
# Plot sample image from MNIST dataset
# epoch = 1, Train loss = 1.1545, Val loss = 0.8087
# epoch = 2, Train loss = 0.7944, Val loss = 0.7632
# epoch = 3, Train loss = 0.7247, Val loss = 0.7389
# epoch = 4, Train loss = 0.6862, Val loss = 0.7215
# epoch = 5, Train loss = 0.6518, Val loss = 0.6935
# epoch = 6, Train loss = 0.6289, Val loss = 0.6867
# epoch = 7, Train loss = 0.5689, Val loss = 0.6616
# epoch = 8, Train loss = 0.5537, Val loss = 0.6638
# epoch = 9, Train loss = 0.5466, Val loss = 0.6633
# epoch = 10, Train loss = 0.5408, Val loss = 0.6637
# Model Performance on SVHN test set
# 0.934810996055603
# Model Performance on MNIST test set
# 0.6395000219345093

# %% [markdown]
# ### **Data augmentation**
#   Apply techniques that increase data diversity and expose the model to a larger variety of samples, thereby improving generalization.
#
#   The main challenge is that SVHN images are colorful and complex, while MNIST is grayscale and much simpler. So, choosing the right Data Augmentation can help the model generalize better and become less sensitive to color differences and background details.
#
#   **Recommended Data Augmentation for this Task:**
#   - Use ColorJitter to Reduce Color Dependence: Brightness and Contrast help the model become robust to different lighting conditions.
#     Saturation is applied slightly to reduce reliance on color. Hue is set to a low value to avoid drastic color shifts.
#   - Adding Noise & Geometric Transformations: Since MNIST consists of handwritten digits that vary in shape and size, the following augmentations will help.
#   - Random Rotation (±10°) to account for slight tilts in digits.
#   - RandomResizedCrop to introduce scale and position variations.
#   - GaussianBlur to reduce dependency on sharp details.
#   - Convert images to grayscale with a 50% probability.
#
#
# **Set " augmentation  : True " and " model_name    : 'augmentation_model' " in cofig.yaml**

# %%
from scripts import main
# Out:
# Base Directory: /content/drive/MyDrive/master-ut/Trustworthy-AI-Mini-Projects/Generalization
# cuda available? True
# Using downloaded and verified file: /content/drive/MyDrive/master-ut/Trustworthy-AI-Mini-Projects/Generalization/data/dataset/train_32x32.mat
# Using downloaded and verified file: /content/drive/MyDrive/master-ut/Trustworthy-AI-Mini-Projects/Generalization/data/dataset/test_32x32.mat
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-0.77521..0.40906325].
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-2.117904..2.64].
# svhn_train_ds: 65932,
# mnist_train_ds: 59932,
# svhn_test_ds: 26032,
# mnist_test_ds: 10000
# Plot sample image from SVHN dataset
# Plot sample image from MNIST dataset
# epoch = 1, Train loss = 1.1705, Val loss = 0.5813
# epoch = 2, Train loss = 0.5457, Val loss = 0.4925
# epoch = 3, Train loss = 0.4510, Val loss = 0.4774
# epoch = 4, Train loss = 0.4212, Val loss = 0.3679
# epoch = 5, Train loss = 0.3627, Val loss = 0.3537
# epoch = 6, Train loss = 0.3354, Val loss = 0.3807
# epoch = 7, Train loss = 0.2651, Val loss = 0.2862
# epoch = 8, Train loss = 0.2477, Val loss = 0.2839
# epoch = 9, Train loss = 0.2369, Val loss = 0.2831
# epoch = 10, Train loss = 0.2311, Val loss = 0.2802
# Model Performance on SVHN test set
# 0.9405347108840942
# Model Performance on MNIST test set
# 0.6608999967575073

# %% [markdown]
# ### Optimizer
# Use another optimizer like Adam.
#
# **Set " optimizer_    : 'Adam' " and " model_name    : 'Adam_model' " in cofig.yaml**

# %%
from scripts import main
# Out:
# Base Directory: /content/drive/MyDrive/master-ut/Trustworthy-AI-Mini-Projects/Generalization
# cuda available? True
# Downloading http://ufldl.stanford.edu/housenumbers/train_32x32.mat to /content/drive/MyDrive/master-ut/Trustworthy-AI-Mini-Projects/Generalization/data/dataset/train_32x32.mat
# 100%|██████████| 182M/182M [00:25<00:00, 7.03MB/s]
# Downloading http://yann.lecun.com/exdb/mnist/train-images-idx3-ubyte.gz
# Failed to download (trying next):
# HTTP Error 404: Not Found
#
# Downloading https://ossci-datasets.s3.amazonaws.com/mnist/train-images-idx3-ubyte.gz
# Downloading https://ossci-datasets.s3.amazonaws.com/mnist/train-images-idx3-ubyte.gz to /content/drive/MyDrive/master-ut/Trustworthy-AI-Mini-Projects/Generalization/data/dataset/MNIST/raw/train-images-idx3-ubyte.gz
# 100%|██████████| 9.91M/9.91M [00:00<00:00, 16.0MB/s]
# Extracting /content/drive/MyDrive/master-ut/Trustworthy-AI-Mini-Projects/Generalization/data/dataset/MNIST/raw/train-images-idx3-ubyte.gz to /content/drive/MyDrive/master-ut/Trustworthy-AI-Mini-Projects/Generalization/data/dataset/MNIST/raw
#
# Downloading http://yann.lecun.com/exdb/mnist/train-labels-idx1-ubyte.gz
# Failed to download (trying next):
# HTTP Error 404: Not Found
#
# Downloading https://ossci-datasets.s3.amazonaws.com/mnist/train-labels-idx1-ubyte.gz
# Downloading https://ossci-datasets.s3.amazonaws.com/mnist/train-labels-idx1-ubyte.gz to /content/drive/MyDrive/master-ut/Trustworthy-AI-Mini-Projects/Generalization/data/dataset/MNIST/raw/train-labels-idx1-ubyte.gz
# 100%|██████████| 28.9k/28.9k [00:00<00:00, 503kB/s]
# Extracting /content/drive/MyDrive/master-ut/Trustworthy-AI-Mini-Projects/Generalization/data/dataset/MNIST/raw/train-labels-idx1-ubyte.gz to /content/drive/MyDrive/master-ut/Trustworthy-AI-Mini-Projects/Generalization/data/dataset/MNIST/raw
#
# Downloading http://yann.lecun.com/exdb/mnist/t10k-images-idx3-ubyte.gz
# Failed to download (trying next):
# HTTP Error 404: Not Found
#
# Downloading https://ossci-datasets.s3.amazonaws.com/mnist/t10k-images-idx3-ubyte.gz
# Downloading https://ossci-datasets.s3.amazonaws.com/mnist/t10k-images-idx3-ubyte.gz to /content/drive/MyDrive/master-ut/Trustworthy-AI-Mini-Projects/Generalization/data/dataset/MNIST/raw/t10k-images-idx3-ubyte.gz
# 100%|██████████| 1.65M/1.65M [00:00<00:00, 4.50MB/s]
# Extracting /content/drive/MyDrive/master-ut/Trustworthy-AI-Mini-Projects/Generalization/data/dataset/MNIST/raw/t10k-images-idx3-ubyte.gz to /content/drive/MyDrive/master-ut/Trustworthy-AI-Mini-Projects/Generalization/data/dataset/MNIST/raw
#
# Downloading http://yann.lecun.com/exdb/mnist/t10k-labels-idx1-ubyte.gz
# Failed to download (trying next):
# HTTP Error 404: Not Found
#
# Downloading https://ossci-datasets.s3.amazonaws.com/mnist/t10k-labels-idx1-ubyte.gz
# Downloading https://ossci-datasets.s3.amazonaws.com/mnist/t10k-labels-idx1-ubyte.gz to /content/drive/MyDrive/master-ut/Trustworthy-AI-Mini-Projects/Generalization/data/dataset/MNIST/raw/t10k-labels-idx1-ubyte.gz
# 100%|██████████| 4.54k/4.54k [00:00<00:00, 6.22MB/s]
# Extracting /content/drive/MyDrive/master-ut/Trustworthy-AI-Mini-Projects/Generalization/data/dataset/MNIST/raw/t10k-labels-idx1-ubyte.gz to /content/drive/MyDrive/master-ut/Trustworthy-AI-Mini-Projects/Generalization/data/dataset/MNIST/raw
#
# Downloading http://ufldl.stanford.edu/housenumbers/test_32x32.mat to /content/drive/MyDrive/master-ut/Trustworthy-AI-Mini-Projects/Generalization/data/dataset/test_32x32.mat
# 100%|██████████| 64.3M/64.3M [00:10<00:00, 5.89MB/s]
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-1.3644148..0.005565486].
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-2.117904..2.622571].
# svhn_train_ds: 65932,
# mnist_train_ds: 59932,
# svhn_test_ds: 26032,
# mnist_test_ds: 10000
# Plot sample image from SVHN dataset
# Plot sample image from MNIST dataset
# epoch = 1, Train loss = 1.4444, Val loss = 0.6815
# epoch = 2, Train loss = 0.4942, Val loss = 0.4212
# epoch = 3, Train loss = 0.3747, Val loss = 0.3507
# epoch = 4, Train loss = 0.3236, Val loss = 0.3134
# epoch = 5, Train loss = 0.2874, Val loss = 0.3041
# epoch = 6, Train loss = 0.2606, Val loss = 0.2771
# epoch = 7, Train loss = 0.1547, Val loss = 0.2345
# epoch = 8, Train loss = 0.1235, Val loss = 0.2443
# epoch = 9, Train loss = 0.1013, Val loss = 0.2545
# epoch = 10, Train loss = 0.0811, Val loss = 0.2699
# Model Performance on SVHN test set
# 0.9339658617973328
# Model Performance on MNIST test set
# 0.656000018119812

# %% [markdown]
# ### Feature extraction
# Use pre-trained models, especially those trained on large datasets like ImageNet, which have learned rich feature representations from diverse data.
# Utilize a pre-trained ResNet-18 model trained on ImageNet (torchvision.models can be used with pretrained=True, or pre-trained weights can be manually loaded into the custom model).
#
# Note: The manually implemented model has different layer naming compared to the prebuilt PyTorch model; therefore, the first approach was used to examine this part.
#
# **Set " pre_train     : True " and " model_name    : 'pretrained_model' " in config.yaml**

# %%
from scripts import main
# Out:
# Base Directory: /content/drive/MyDrive/master-ut/Trustworthy-AI-Mini-Projects/Generalization
# cuda available? True
# Downloading http://ufldl.stanford.edu/housenumbers/train_32x32.mat to /content/drive/MyDrive/master-ut/Trustworthy-AI-Mini-Projects/Generalization/data/dataset/train_32x32.mat
# 100%|██████████| 182M/182M [00:05<00:00, 31.0MB/s]
# Downloading http://yann.lecun.com/exdb/mnist/train-images-idx3-ubyte.gz
# Failed to download (trying next):
# HTTP Error 404: Not Found
#
# Downloading https://ossci-datasets.s3.amazonaws.com/mnist/train-images-idx3-ubyte.gz
# Downloading https://ossci-datasets.s3.amazonaws.com/mnist/train-images-idx3-ubyte.gz to /content/drive/MyDrive/master-ut/Trustworthy-AI-Mini-Projects/Generalization/data/dataset/MNIST/raw/train-images-idx3-ubyte.gz
# 100%|██████████| 9.91M/9.91M [00:00<00:00, 16.1MB/s]
# Extracting /content/drive/MyDrive/master-ut/Trustworthy-AI-Mini-Projects/Generalization/data/dataset/MNIST/raw/train-images-idx3-ubyte.gz to /content/drive/MyDrive/master-ut/Trustworthy-AI-Mini-Projects/Generalization/data/dataset/MNIST/raw
#
# Downloading http://yann.lecun.com/exdb/mnist/train-labels-idx1-ubyte.gz
# Failed to download (trying next):
# HTTP Error 404: Not Found
#
# Downloading https://ossci-datasets.s3.amazonaws.com/mnist/train-labels-idx1-ubyte.gz
# Downloading https://ossci-datasets.s3.amazonaws.com/mnist/train-labels-idx1-ubyte.gz to /content/drive/MyDrive/master-ut/Trustworthy-AI-Mini-Projects/Generalization/data/dataset/MNIST/raw/train-labels-idx1-ubyte.gz
# 100%|██████████| 28.9k/28.9k [00:00<00:00, 499kB/s]
# Extracting /content/drive/MyDrive/master-ut/Trustworthy-AI-Mini-Projects/Generalization/data/dataset/MNIST/raw/train-labels-idx1-ubyte.gz to /content/drive/MyDrive/master-ut/Trustworthy-AI-Mini-Projects/Generalization/data/dataset/MNIST/raw
#
# Downloading http://yann.lecun.com/exdb/mnist/t10k-images-idx3-ubyte.gz
# Failed to download (trying next):
# HTTP Error 404: Not Found
#
# Downloading https://ossci-datasets.s3.amazonaws.com/mnist/t10k-images-idx3-ubyte.gz
# Downloading https://ossci-datasets.s3.amazonaws.com/mnist/t10k-images-idx3-ubyte.gz to /content/drive/MyDrive/master-ut/Trustworthy-AI-Mini-Projects/Generalization/data/dataset/MNIST/raw/t10k-images-idx3-ubyte.gz
# 100%|██████████| 1.65M/1.65M [00:00<00:00, 4.46MB/s]
# Extracting /content/drive/MyDrive/master-ut/Trustworthy-AI-Mini-Projects/Generalization/data/dataset/MNIST/raw/t10k-images-idx3-ubyte.gz to /content/drive/MyDrive/master-ut/Trustworthy-AI-Mini-Projects/Generalization/data/dataset/MNIST/raw
#
# Downloading http://yann.lecun.com/exdb/mnist/t10k-labels-idx1-ubyte.gz
# Failed to download (trying next):
# HTTP Error 404: Not Found
#
# Downloading https://ossci-datasets.s3.amazonaws.com/mnist/t10k-labels-idx1-ubyte.gz
# Downloading https://ossci-datasets.s3.amazonaws.com/mnist/t10k-labels-idx1-ubyte.gz to /content/drive/MyDrive/master-ut/Trustworthy-AI-Mini-Projects/Generalization/data/dataset/MNIST/raw/t10k-labels-idx1-ubyte.gz
# 100%|██████████| 4.54k/4.54k [00:00<00:00, 9.73MB/s]
# Extracting /content/drive/MyDrive/master-ut/Trustworthy-AI-Mini-Projects/Generalization/data/dataset/MNIST/raw/t10k-labels-idx1-ubyte.gz to /content/drive/MyDrive/master-ut/Trustworthy-AI-Mini-Projects/Generalization/data/dataset/MNIST/raw
#
# Downloading http://ufldl.stanford.edu/housenumbers/test_32x32.mat to /content/drive/MyDrive/master-ut/Trustworthy-AI-Mini-Projects/Generalization/data/dataset/test_32x32.mat
# 100%|██████████| 64.3M/64.3M [00:07<00:00, 8.74MB/s]
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-1.5455182..1.8731157].
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-2.117904..2.64].
# svhn_train_ds: 65932,
# mnist_train_ds: 59932,
# svhn_test_ds: 26032,
# mnist_test_ds: 10000
# Plot sample image from SVHN dataset
# Plot sample image from MNIST dataset
# /usr/local/lib/python3.11/dist-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=ResNet18_Weights.IMAGENET1K_V1`. You can also use `weights=ResNet18_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)
# Downloading: "https://download.pytorch.org/models/resnet18-f37072fd.pth" to /root/.cache/torch/hub/checkpoints/resnet18-f37072fd.pth
# 100%|██████████| 44.7M/44.7M [00:00<00:00, 165MB/s]
# epoch = 1, Train loss = 0.5849, Val loss = 0.3176
# epoch = 2, Train loss = 0.3010, Val loss = 0.2986
# epoch = 3, Train loss = 0.2290, Val loss = 0.2537
# epoch = 4, Train loss = 0.1954, Val loss = 0.2417
# epoch = 5, Train loss = 0.1598, Val loss = 0.2477
# epoch = 6, Train loss = 0.1368, Val loss = 0.2585
# epoch = 7, Train loss = 0.0732, Val loss = 0.2260
# epoch = 8, Train loss = 0.0518, Val loss = 0.2385
# epoch = 9, Train loss = 0.0418, Val loss = 0.2551
# epoch = 10, Train loss = 0.0346, Val loss = 0.2645
# Model Performance on SVHN test set
# 0.9424554109573364
# Model Performance on MNIST test set
# 0.5016999840736389

# %% [markdown]
# ## Final model
# ### The best combination from the above settings to evaluate cross-dataset generalization.
#
# Make the following changes to the config.yaml file:
# - loss_function : 'LSCE'
# - optimizer_    : 'Adam'
# - augmentation  : True
# - use_batch_norm: True
# - pre_train     : False
# - model_name    : 'best_model_svhn'

# %%
from scripts import main
# Out:
# Base Directory: /content/drive/MyDrive/master-ut/Trustworthy-AI-Mini-Projects/Generalization
# cuda available? True
# Downloading http://ufldl.stanford.edu/housenumbers/train_32x32.mat to /content/drive/MyDrive/master-ut/Trustworthy-AI-Mini-Projects/Generalization/data/dataset/train_32x32.mat
# 100%|██████████| 182M/182M [00:53<00:00, 3.39MB/s]
# Downloading http://yann.lecun.com/exdb/mnist/train-images-idx3-ubyte.gz
# Failed to download (trying next):
# HTTP Error 404: Not Found
#
# Downloading https://ossci-datasets.s3.amazonaws.com/mnist/train-images-idx3-ubyte.gz
# Downloading https://ossci-datasets.s3.amazonaws.com/mnist/train-images-idx3-ubyte.gz to /content/drive/MyDrive/master-ut/Trustworthy-AI-Mini-Projects/Generalization/data/dataset/MNIST/raw/train-images-idx3-ubyte.gz
# 100%|██████████| 9.91M/9.91M [00:11<00:00, 883kB/s]
# Extracting /content/drive/MyDrive/master-ut/Trustworthy-AI-Mini-Projects/Generalization/data/dataset/MNIST/raw/train-images-idx3-ubyte.gz to /content/drive/MyDrive/master-ut/Trustworthy-AI-Mini-Projects/Generalization/data/dataset/MNIST/raw
#
# Downloading http://yann.lecun.com/exdb/mnist/train-labels-idx1-ubyte.gz
# Failed to download (trying next):
# HTTP Error 404: Not Found
#
# Downloading https://ossci-datasets.s3.amazonaws.com/mnist/train-labels-idx1-ubyte.gz
# Downloading https://ossci-datasets.s3.amazonaws.com/mnist/train-labels-idx1-ubyte.gz to /content/drive/MyDrive/master-ut/Trustworthy-AI-Mini-Projects/Generalization/data/dataset/MNIST/raw/train-labels-idx1-ubyte.gz
# 100%|██████████| 28.9k/28.9k [00:00<00:00, 57.5kB/s]
# Extracting /content/drive/MyDrive/master-ut/Trustworthy-AI-Mini-Projects/Generalization/data/dataset/MNIST/raw/train-labels-idx1-ubyte.gz to /content/drive/MyDrive/master-ut/Trustworthy-AI-Mini-Projects/Generalization/data/dataset/MNIST/raw
#
# Downloading http://yann.lecun.com/exdb/mnist/t10k-images-idx3-ubyte.gz
# Failed to download (trying next):
# HTTP Error 404: Not Found
#
# Downloading https://ossci-datasets.s3.amazonaws.com/mnist/t10k-images-idx3-ubyte.gz
# Downloading https://ossci-datasets.s3.amazonaws.com/mnist/t10k-images-idx3-ubyte.gz to /content/drive/MyDrive/master-ut/Trustworthy-AI-Mini-Projects/Generalization/data/dataset/MNIST/raw/t10k-images-idx3-ubyte.gz
# 100%|██████████| 1.65M/1.65M [00:01<00:00, 1.22MB/s]
# Extracting /content/drive/MyDrive/master-ut/Trustworthy-AI-Mini-Projects/Generalization/data/dataset/MNIST/raw/t10k-images-idx3-ubyte.gz to /content/drive/MyDrive/master-ut/Trustworthy-AI-Mini-Projects/Generalization/data/dataset/MNIST/raw
#
# Downloading http://yann.lecun.com/exdb/mnist/t10k-labels-idx1-ubyte.gz
# Failed to download (trying next):
# HTTP Error 404: Not Found
#
# Downloading https://ossci-datasets.s3.amazonaws.com/mnist/t10k-labels-idx1-ubyte.gz
# Downloading https://ossci-datasets.s3.amazonaws.com/mnist/t10k-labels-idx1-ubyte.gz to /content/drive/MyDrive/master-ut/Trustworthy-AI-Mini-Projects/Generalization/data/dataset/MNIST/raw/t10k-labels-idx1-ubyte.gz
# 100%|██████████| 4.54k/4.54k [00:00<00:00, 9.69MB/s]
# Extracting /content/drive/MyDrive/master-ut/Trustworthy-AI-Mini-Projects/Generalization/data/dataset/MNIST/raw/t10k-labels-idx1-ubyte.gz to /content/drive/MyDrive/master-ut/Trustworthy-AI-Mini-Projects/Generalization/data/dataset/MNIST/raw
#
# Downloading http://ufldl.stanford.edu/housenumbers/test_32x32.mat to /content/drive/MyDrive/master-ut/Trustworthy-AI-Mini-Projects/Generalization/data/dataset/test_32x32.mat
# 100%|██████████| 64.3M/64.3M [00:19<00:00, 3.24MB/s]
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-0.9677871..2.4308496].
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-2.117904..2.64].
# svhn_train_ds: 65932,
# mnist_train_ds: 59932,
# svhn_test_ds: 26032,
# mnist_test_ds: 10000
# Plot sample image from SVHN dataset
# Plot sample image from MNIST dataset
# epoch = 1, Train loss = 1.8782, Val loss = 1.2801
# epoch = 2, Train loss = 1.0440, Val loss = 0.9826
# epoch = 3, Train loss = 0.8905, Val loss = 0.8683
# epoch = 4, Train loss = 0.8418, Val loss = 0.8029
# epoch = 5, Train loss = 0.8135, Val loss = 0.7962
# epoch = 6, Train loss = 0.7920, Val loss = 0.8383
# epoch = 7, Train loss = 0.7146, Val loss = 0.7154
# epoch = 8, Train loss = 0.6943, Val loss = 0.7129
# epoch = 9, Train loss = 0.6854, Val loss = 0.7040
# epoch = 10, Train loss = 0.6783, Val loss = 0.7020
# Model Performance on SVHN test set
# 0.9432621598243713
# Model Performance on MNIST test set
# 0.7544000148773193

# %% [markdown]
# # Results
#
# |Test accuracy |  svhn  |  mnist |
# |--------------|--------|--------|
# | base         | 0.9325 | 0.5845 |
# | remove BN    | 0.9320 | 0.6118 |
# | LSCE         | 0.9348 | 0.6395 |
# | augmentation | 0.9405 | 0.6608 |
# | Adam         | 0.9339 | 0.6560 |
# | pre-train    | 0.9424 | 0.5016 |
# | best model   | 0.9432 | 0.7544 |
